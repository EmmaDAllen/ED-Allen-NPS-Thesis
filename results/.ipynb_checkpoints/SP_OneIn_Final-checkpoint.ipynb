# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df_trop = pd.read_csv('training_log_tropical_shortest_path_onein_final.csv')
df_trop_v2 = pd.read_csv('training_log_tropical_v2_shortest_path_onein_final.csv')
df_trans = pd.read_csv('training_log_transformer_shortest_path_onein_final.csv')
df_edge = pd.read_csv('training_log_edge_transformer_shortest_path_onein_final.csv')
df_gnn = pd.read_csv('training_log_gnn_shortest_path_onein_final.csv')

# %%
df_trop["model_type"] = "tropical"
df_trop_v2["model_type"] = "tropical_v2"
df_trans["model_type"] = "transformer"
df_edge["model_type"] = "edge_transformer"
df_gnn["model_type"] = "gnn"

df_all = pd.concat([df_trop, df_trop_v2, df_trans, df_edge, df_gnn], ignore_index=True)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

sns.lineplot(
    data=df_all,
    x="epoch",
    y="train_loss",
    hue="model_type",
    ax=axes[0]
)

axes[0].set_title("Training Loss by Epoch")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Training Loss")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="val_loss",
    hue="model_type",
    ax=axes[1]
)

axes[1].set_title("Validation Loss by Epoch")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Validation Loss")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharex=True)

sns.lineplot(
    data=df_all,
    x="epoch",
    y="exact_match",
    hue="model_type",
    ax=axes[0, 0]
)
axes[0, 0].set_title("Exact Match by Epoch")
axes[0, 0].set_xlabel("Epoch")
axes[0, 0].set_ylabel("Exact Match Rate")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="hamming",
    hue="model_type",
    ax=axes[0, 1]
)
axes[0, 1].set_title("Hamming Distance by Epoch")
axes[0, 1].set_xlabel("Epoch")
axes[0, 1].set_ylabel("Hamming Distance")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="f1",
    hue="model_type",
    ax=axes[1, 0]
)
axes[1, 0].set_title("F1 Score by Epoch")
axes[1, 0].set_xlabel("Epoch")
axes[1, 0].set_ylabel("F1 Score")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="epoch_time_seconds",
    hue="model_type",
    ax=axes[1, 1]
)
axes[1, 1].set_title("Epoch Time by Epoch")
axes[1, 1].set_xlabel("Epoch")
axes[1, 1].set_ylabel("Time (seconds)")

plt.tight_layout()
plt.show()

# %%
df_tropical_eval = pd.read_csv('evaluation_results_tropical_shortest_path_id_new_onein_final.csv')
df_tropical_v2_eval = pd.read_csv('evaluation_results_tropical_v2_shortest_path_id_new_onein_final.csv')
df_transformer_eval = pd.read_csv('evaluation_results_transformer_shortest_path_id_new_onein_final.csv')
df_edge_eval = pd.read_csv('evaluation_results_edge_transformer_shortest_path_id_new_onein_final.csv')
df_gnn_eval = pd.read_csv('evaluation_results_gnn_shortest_path_id_new_onein_final.csv')

# %%
df_tropical_eval = pd.read_csv('evaluation_results_tropical_shortest_path_ood_size_onein_final.csv')
df_tropical_v2_eval = pd.read_csv('evaluation_results_tropical_v2_shortest_path_ood_size_onein_final.csv')
df_transformer_eval = pd.read_csv('evaluation_results_transformer_shortest_path_ood_size_onein_final.csv')
df_edge_eval = pd.read_csv('evaluation_results_edge_transformer_shortest_path_ood_size_onein_final.csv')
df_gnn_eval = pd.read_csv('evaluation_results_gnn_shortest_path_ood_size_onein_final.csv')

# %%
df_tropical_eval = pd.read_csv('evaluation_results_tropical_shortest_path_wood_onein_final.csv')
df_tropical_v2_eval = pd.read_csv('evaluation_results_tropical_v2_shortest_path_wood_onein_final.csv')
df_transformer_eval = pd.read_csv('evaluation_results_transformer_shortest_path_wood_onein_final.csv')
df_edge_eval = pd.read_csv('evaluation_results_edge_transformer_shortest_path_wood_onein_final.csv')
df_gnn_eval = pd.read_csv('evaluation_results_gnn_shortest_path_wood_onein_final.csv')

# %%
df_tropical_eval["model_type"] = "tropical"
df_tropical_v2_eval["model_type"] = "tropical_v2"
df_transformer_eval["model_type"] = "transformer"
df_gnn_eval["model_type"] = "gnn"
df_edge_eval["model_type"] = "edge_transformer"


df_all_eval = pd.concat([df_gnn_eval, df_edge_eval, df_tropical_v2_eval],ignore_index=True)

df_all_eval.head()
# Out:
#   model_type   problem_type eval_mode  wood_problem  network_name  graph_seed  \
# 0        gnn  shortest_path  ood_size           NaN           NaN    10020005
# 1        gnn  shortest_path  ood_size           NaN           NaN    10020006
# 2        gnn  shortest_path  ood_size           NaN           NaN    10020007
# 3        gnn  shortest_path  ood_size           NaN           NaN    10020008
# 4        gnn  shortest_path  ood_size           NaN           NaN    10020009
#
#    n_nodes  n_edges  density  replication  source  sink  attack_limit  \
# 0      100      200      2.0            0       0    99             1
# 1      100      200      2.0            1       0    99             1
# 2      100      200      2.0            2       0    99             1
# 3      100      200      2.0            3       0    99             1
# 4      100      200      2.0            4       0    99             1
#
#    optimal_objective  predicted_objective  objective_gap  hamming_distance  \
# 0               57.0                   50       0.122807                 2
# 1               18.0                   14       0.222222                 2
# 2               35.0                   34       0.028571                 2
# 3               38.0                   29       0.236842                 2
# 4               28.0                   28       0.000000                 0
#
#    exact_match  num_correct_edges  num_predicted_attacks  num_optimal_attacks  \
# 0            0                  0                      1                    1
# 1            0                  0                      1                    1
# 2            0                  0                      1                    1
# 3            0                  0                      1                    1
# 4            1                  1                      1                    1
#
#    mip_solve_time  mip_total_time  inference_time  candidate_objective  \
# 0        0.160575        0.169320        0.167637                   53
# 1        0.042547        0.049451        0.001101                   18
# 2        0.045318        0.052250        0.000936                   34
# 3        0.041739        0.049302        0.000919                   36
# 4        0.042665        0.049581        0.000935                   28
#
#    candidate_objective_gap  candidate_pool_size  num_candidates  \
# 0                 0.070175                    4               4
# 1                 0.000000                    4               4
# 2                 0.028571                    4               4
# 3                 0.052632                    4               4
# 4                 0.000000                    4               4
#
#    candidate_search_time  hybrid_total_time  candidate_exact_match  \
# 0               0.013106           0.180743                      0
# 1               0.001565           0.002666                      1
# 2               0.001849           0.002785                      0
# 3               0.001679           0.002598                      0
# 4               0.001412           0.002347                      1
#
#    candidate_hamming_distance  candidate_correct_edges
# 0                           2                        0
# 1                           0                        1
# 2                           2                        0
# 3                           2                        0
# 4                           0                        1

# %%
summary = (
    df_all_eval.groupby(["model_type", "density"])
    .agg(
        count=("objective_gap", "count"),

        # Direct model prediction
        exact_match_avg=("exact_match", "mean"),
        exact_match_std=("exact_match", "std"),

        candidate_exact_match_avg=("candidate_exact_match", "mean"),
        candidate_exact_match_std=("candidate_exact_match", "std"),

        objective_gap_avg=("objective_gap", "mean"),
        objective_gap_median=("objective_gap", "median"),
        objective_gap_std=("objective_gap", "std"),

        candidate_objective_gap_avg=("candidate_objective_gap", "mean"),
        candidate_objective_gap_median=("candidate_objective_gap", "median"),
        candidate_objective_gap_std=("candidate_objective_gap", "std"),

        hamming_distance_avg=("hamming_distance", "mean"),
        hamming_distance_std=("hamming_distance", "std"),

        candidate_hamming_distance_avg=("candidate_hamming_distance", "mean"),
        candidate_hamming_distance_std=("candidate_hamming_distance", "std"),

        inference_time_avg=("inference_time", "mean"),
        inference_time_std=("inference_time", "std"),

        hybrid_total_time_avg=("hybrid_total_time", "mean"),
        hybrid_total_time_std=("hybrid_total_time", "std"),

        mip_solve_time_avg=("mip_solve_time", "mean"),
        mip_solve_time_std=("mip_solve_time", "std"),

        candidate_correct_edges_avg=("candidate_correct_edges", "mean"),
        candidate_correct_edges_std=("candidate_correct_edges", "std"),

        candidate_search_time_avg=("candidate_search_time", "mean"),
        candidate_search_time_std=("candidate_search_time", "std"),

        candidate_pool_size_avg=("candidate_pool_size", "mean"),
        num_candidates_avg=("num_candidates", "mean"),


    )
    .reset_index()
)

summary
# Out:
#           model_type  density  count  exact_match_avg  exact_match_std  \
# 0   edge_transformer      2.0    400           0.0625         0.242365
# 1   edge_transformer      2.5    400           0.0750         0.263721
# 2   edge_transformer      3.0    400           0.0700         0.255467
# 3   edge_transformer      4.0    400           0.0850         0.279231
# 4   edge_transformer      5.0    400           0.0775         0.267718
# 5   edge_transformer      6.0    400           0.1100         0.313282
# 6   edge_transformer      8.0    400           0.0850         0.279231
# 7                gnn      2.0    400           0.0725         0.259639
# 8                gnn      2.5    400           0.0750         0.263721
# 9                gnn      3.0    400           0.0750         0.263721
# 10               gnn      4.0    400           0.0725         0.259639
# 11               gnn      5.0    400           0.0850         0.279231
# 12               gnn      6.0    400           0.0875         0.282920
# 13               gnn      8.0    400           0.0900         0.286540
# 14       tropical_v2      2.0    400           0.0650         0.246835
# 15       tropical_v2      2.5    400           0.0800         0.271633
# 16       tropical_v2      3.0    400           0.0700         0.255467
# 17       tropical_v2      4.0    400           0.0850         0.279231
# 18       tropical_v2      5.0    400           0.1075         0.310136
# 19       tropical_v2      6.0    400           0.1100         0.313282
# 20       tropical_v2      8.0    400           0.0900         0.286540
#
#     candidate_exact_match_avg  candidate_exact_match_std  objective_gap_avg  \
# 0                      0.1125                   0.316376           0.150338
# 1                      0.1850                   0.388784           0.151349
# 2                      0.1800                   0.384669           0.154124
# 3                      0.2025                   0.402366           0.153344
# 4                      0.2425                   0.429132           0.138964
# 5                      0.2100                   0.407818           0.131967
# 6                      0.2425                   0.429132           0.141255
# 7                      0.1700                   0.376103           0.135483
# 8                      0.2150                   0.411337           0.146735
# 9                      0.2375                   0.426084           0.142637
# 10                     0.2125                   0.409589           0.152151
# 11                     0.2375                   0.426084           0.136618
# 12                     0.2050                   0.404207           0.135476
# 13                     0.2300                   0.421360           0.132950
# 14                     0.1675                   0.373889           0.135868
# 15                     0.2200                   0.414765           0.140205
# 16                     0.2475                   0.432100           0.143274
# 17                     0.1875                   0.390801           0.156511
# 18                     0.2425                   0.429132           0.131004
# 19                     0.2275                   0.419743           0.127453
# 20                     0.2200                   0.414765           0.148818
#
#     objective_gap_median  objective_gap_std  candidate_objective_gap_avg  \
# 0               0.142857           0.103322                     0.114265
# 1               0.141851           0.109916                     0.093679
# 2               0.140873           0.115035                     0.090306
# 3               0.140873           0.117289                     0.078362
# 4               0.111111           0.129572                     0.056834
# 5               0.117647           0.115828                     0.064404
# 6               0.125000           0.121895                     0.050461
# 7               0.122379           0.100875                     0.069590
# 8               0.140598           0.112870                     0.082008
# 9               0.129032           0.110914                     0.069096
# 10              0.137931           0.116463                     0.071124
# 11              0.117647           0.123753                     0.055402
# 12              0.125000           0.109926                     0.063730
# 13              0.113248           0.112749                     0.049453
# 14              0.126599           0.097287                     0.068897
# 15              0.131884           0.107516                     0.073396
# 16              0.131007           0.107789                     0.061386
# 17              0.142857           0.116844                     0.069417
# 18              0.109127           0.125589                     0.049109
# 19              0.115385           0.111998                     0.051505
# 20              0.133333           0.124276                     0.061145
#
#     candidate_objective_gap_median  candidate_objective_gap_std  \
# 0                     1.037094e-01                     0.098087
# 1                     7.500000e-02                     0.096429
# 2                     6.857367e-02                     0.096923
# 3                     4.000000e-02                     0.097898
# 4                     6.840127e-15                     0.085779
# 5                     1.031864e-13                     0.089187
# 6                     4.958353e-15                     0.079477
# 7                     5.357143e-02                     0.069470
# 8                     5.263158e-02                     0.094573
# 9                     3.448276e-02                     0.090230
# 10                    3.333333e-02                     0.090612
# 11                    3.034610e-15                     0.088464
# 12                    4.532773e-14                     0.088431
# 13                    5.092223e-15                     0.081889
# 14                    5.298246e-02                     0.068885
# 15                    4.124150e-02                     0.088713
# 16                    2.817460e-02                     0.081672
# 17                    3.571429e-02                     0.087436
# 18                    2.375822e-15                     0.081797
# 19                    9.210739e-15                     0.077345
# 20                    2.262388e-14                     0.085269
#
#     hamming_distance_avg  hamming_distance_std  \
# 0                 3.9125              2.206130
# 1                 3.5500              2.041548
# 2                 3.5475              2.050183
# 3                 3.5325              2.165796
# 4                 3.1225              1.800165
# 5                 3.2200              1.966282
# 6                 3.2825              1.931845
# 7                 3.6225              2.042161
# 8                 3.4350              1.992662
# 9                 3.3525              1.981934
# 10                3.6225              2.132219
# 11                3.2625              1.875470
# 12                3.3250              1.966989
# 13                3.3225              1.987049
# 14                3.6575              2.079906
# 15                3.4300              1.991234
# 16                3.3875              1.921347
# 17                3.5775              2.114277
# 18                3.1575              1.931845
# 19                3.2000              1.960768
# 20                3.2675              1.881434
#
#     candidate_hamming_distance_avg  candidate_hamming_distance_std  \
# 0                           3.5675                        2.280009
# 1                           3.0500                        2.197629
# 2                           2.9725                        2.131455
# 3                           2.9625                        2.259171
# 4                           2.4775                        1.940078
# 5                           2.6800                        1.985562
# 6                           2.5625                        2.074090
# 7                           2.9625                        2.089740
# 8                           2.7800                        2.083856
# 9                           2.6025                        2.030962
# 10                          2.8925                        2.212053
# 11                          2.5375                        2.038131
# 12                          2.7600                        2.051321
# 13                          2.6675                        2.091142
# 14                          2.9625                        2.111217
# 15                          2.7550                        2.049506
# 16                          2.5725                        2.047003
# 17                          2.9175                        2.160408
# 18                          2.4225                        1.942531
# 19                          2.6000                        2.013737
# 20                          2.6925                        2.044111
#
#     inference_time_avg  inference_time_std  hybrid_total_time_avg  \
# 0             0.002289            0.007992               0.034890
# 1             0.002092            0.000383               0.042804
# 2             0.002333            0.000683               0.048735
# 3             0.003062            0.001456               0.061440
# 4             0.004168            0.002771               0.071855
# 5             0.005313            0.003984               0.083391
# 6             0.008521            0.007006               0.108080
# 7             0.001481            0.008329               0.032856
# 8             0.001106            0.000232               0.040369
# 9             0.001115            0.000076               0.044671
# 10            0.001161            0.000093               0.058051
# 11            0.001322            0.000323               0.064335
# 12            0.001454            0.000533               0.075729
# 13            0.001999            0.001077               0.102308
# 14            0.007848            0.027666               0.040668
# 15            0.007294            0.002150               0.047249
# 16            0.008439            0.003281               0.055102
# 17            0.011250            0.006687               0.068204
# 18            0.015474            0.010839               0.082101
# 19            0.020644            0.015903               0.092096
# 20            0.033367            0.029251               0.129120
#
#     hybrid_total_time_std  mip_solve_time_avg  mip_solve_time_std  \
# 0                0.045667            0.258980            0.326470
# 1                0.055790            0.554270            0.944262
# 2                0.062819            0.872247            1.318801
# 3                0.073115            1.497234            1.964133
# 4                0.084668            2.016350            2.715222
# 5                0.097840            3.524068            4.426103
# 6                0.115931            5.477856            6.377899
# 7                0.040910            0.254430            0.317464
# 8                0.051292            0.547606            0.931604
# 9                0.054425            0.867019            1.315048
# 10               0.071371            1.489217            1.949469
# 11               0.072088            2.008110            2.702136
# 12               0.086246            3.515196            4.423088
# 13               0.118584            5.463049            6.364388
# 14               0.057788            0.256972            0.319253
# 15               0.058920            0.553499            0.938174
# 16               0.067149            0.873166            1.324207
# 17               0.080072            1.496337            1.962185
# 18               0.090049            2.015627            2.720909
# 19               0.090475            3.530648            4.442490
# 20               0.134463            5.499613            6.407663
#
#     candidate_correct_edges_avg  candidate_correct_edges_std  \
# 0                        1.1775                     0.850177
# 1                        1.4550                     1.022540
# 2                        1.4700                     0.983116
# 3                        1.4900                     1.112652
# 4                        1.6775                     1.149695
# 5                        1.5950                     1.172353
# 6                        1.6700                     1.284611
# 7                        1.4800                     1.001052
# 8                        1.5900                     1.076940
# 9                        1.6550                     1.155124
# 10                       1.5250                     1.132511
# 11                       1.6475                     1.179713
# 12                       1.5550                     1.155558
# 13                       1.6175                     1.228808
# 14                       1.4800                     0.978260
# 15                       1.6025                     1.085098
# 16                       1.6700                     1.131061
# 17                       1.5125                     1.143728
# 18                       1.7050                     1.190175
# 19                       1.6350                     1.241220
# 20                       1.6050                     1.268067
#
#     candidate_search_time_avg  candidate_search_time_std  \
# 0                    0.032601                   0.045078
# 1                    0.040712                   0.055633
# 2                    0.046402                   0.062490
# 3                    0.058378                   0.072481
# 4                    0.067687                   0.083288
# 5                    0.078078                   0.095818
# 6                    0.099559                   0.112067
# 7                    0.031375                   0.040224
# 8                    0.039262                   0.051273
# 9                    0.043556                   0.054401
# 10                   0.056890                   0.071344
# 11                   0.063013                   0.071942
# 12                   0.074275                   0.086040
# 13                   0.100309                   0.118106
# 14                   0.032819                   0.050877
# 15                   0.039955                   0.057958
# 16                   0.046663                   0.065699
# 17                   0.056954                   0.076712
# 18                   0.066626                   0.084439
# 19                   0.071452                   0.081277
# 20                   0.095754                   0.116636
#
#     candidate_pool_size_avg  num_candidates_avg
# 0                       6.0                25.0
# 1                       6.0                25.0
# 2                       6.0                25.0
# 3                       6.0                25.0
# 4                       6.0                25.0
# 5                       6.0                25.0
# 6                       6.0                25.0
# 7                       6.0                25.0
# 8                       6.0                25.0
# 9                       6.0                25.0
# 10                      6.0                25.0
# 11                      6.0                25.0
# 12                      6.0                25.0
# 13                      6.0                25.0
# 14                      6.0                25.0
# 15                      6.0                25.0
# 16                      6.0                25.0
# 17                      6.0                25.0
# 18                      6.0                25.0
# 19                      6.0                25.0
# 20                      6.0                25.0

# %%
def add_confidence_intervals(summary, metrics, confidence_multiplier=1.96):

    for metric in metrics:
        mean_col = f"{metric}_avg"
        std_col = f"{metric}_std"

        summary[f"{metric}_se"] = (summary[std_col] / np.sqrt(summary["count"]))

        summary[f"{metric}_ci_lower"] = (summary[mean_col] - confidence_multiplier * summary[f"{metric}_se"])

        summary[f"{metric}_ci_upper"] = (summary[mean_col] + confidence_multiplier * summary[f"{metric}_se"])

    return summary

# %%
metrics_for_ci = [
    # Direct model prediction
    "exact_match",
    "objective_gap",
    "hamming_distance",
    "inference_time",

    # Candidate search / hybrid
    "candidate_exact_match",
    "candidate_objective_gap",
    "candidate_hamming_distance",
    "candidate_search_time",
    "hybrid_total_time",

    # MIP benchmark
    "mip_solve_time",
]

summary = add_confidence_intervals(summary, metrics_for_ci)

# %%
def plot_metric_with_ci(summary, metric, xlabel="Arc-to-Node Ratio (m/n)", ylabel=None, title=None):
    
    plt.figure(figsize=(9, 6))

    for model, group in summary.groupby("model_type"):
        group = group.sort_values("density")

        line, = plt.plot(
            group["density"],
            group[f"{metric}_avg"],
            marker="o",
            label=model)

        plt.plot(
            group["density"],
            group[f"{metric}_ci_lower"],
            linestyle="--",
            color=line.get_color(),
            alpha=0.6)

        plt.plot(
            group["density"],
            group[f"{metric}_ci_upper"],
            linestyle="--",
            color=line.get_color(),
            alpha=0.6)

    plt.xlabel(xlabel)
    plt.ylabel(ylabel if ylabel else metric)
    plt.title(title if title else f"{metric} by Network Density")
    plt.legend(title="Model")
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
plot_metric_with_ci(
    summary,
    metric="objective_gap",
    ylabel="Average Objective Gap",
    title="Average Objective Gap by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="exact_match",
    ylabel="Average Exact Match",
    title="Average Exact Match by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="hamming_distance",
    ylabel="Average Hamming Distance",
    title="Average Hamming Distance by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="inference_time",
    ylabel="Average Model Inference Time",
    title="Average Model Inference Time by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_exact_match",
    ylabel="Average Candidate Exact Match",
    title="Average Candidate Exact Match by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_objective_gap",
    ylabel="Average Candidate Objective Gap",
    title="Average Candidate Objective Gap by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_hamming_distance",
    ylabel="Average Candidate Hamming Distance",
    title="Average Candidate Hamming Distance by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_search_time",
    ylabel="Average Candidate Search Time",
    title="Average Candidate Search Time by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="hybrid_total_time",
    ylabel="Average Candidate Search + Model Inference Time",
    title="Average Candidate Search + Model Inference Time by Network Density"
)
