# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df_trop = pd.read_csv('training_log_tropical_shortest_path_onein_final.csv')
df_trop_v2 = pd.read_csv('training_log_tropical_v2_shortest_path_onein_final.csv')
df_trans = pd.read_csv('training_log_transformer_shortest_path_onein_final.csv')
df_edge = pd.read_csv('training_log_edge_transformer_shortest_path_onein_final.csv')
df_gnn = pd.read_csv('training_log_gnn_shortest_path_onein_final.csv')

# %%
df_trop["model_type"] = "tropical"
df_trop_v2["model_type"] = "tropical_v2"
df_trans["model_type"] = "transformer"
df_edge["model_type"] = "edge_transformer"
df_gnn["model_type"] = "gnn"

df_all = pd.concat([df_trop, df_trop_v2, df_trans, df_edge, df_gnn], ignore_index=True)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

sns.lineplot(
    data=df_all,
    x="epoch",
    y="train_loss",
    hue="model_type",
    ax=axes[0]
)

axes[0].set_title("Training Loss by Epoch")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Training Loss")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="val_loss",
    hue="model_type",
    ax=axes[1]
)

axes[1].set_title("Validation Loss by Epoch")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Validation Loss")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharex=True)

sns.lineplot(
    data=df_all,
    x="epoch",
    y="exact_match",
    hue="model_type",
    ax=axes[0, 0]
)
axes[0, 0].set_title("Exact Match by Epoch")
axes[0, 0].set_xlabel("Epoch")
axes[0, 0].set_ylabel("Exact Match Rate")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="hamming",
    hue="model_type",
    ax=axes[0, 1]
)
axes[0, 1].set_title("Hamming Distance by Epoch")
axes[0, 1].set_xlabel("Epoch")
axes[0, 1].set_ylabel("Hamming Distance")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="f1",
    hue="model_type",
    ax=axes[1, 0]
)
axes[1, 0].set_title("F1 Score by Epoch")
axes[1, 0].set_xlabel("Epoch")
axes[1, 0].set_ylabel("F1 Score")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="epoch_time_seconds",
    hue="model_type",
    ax=axes[1, 1]
)
axes[1, 1].set_title("Epoch Time by Epoch")
axes[1, 1].set_xlabel("Epoch")
axes[1, 1].set_ylabel("Time (seconds)")

plt.tight_layout()
plt.show()

# %%
df_tropical_eval = pd.read_csv('evaluation_results_tropical_shortest_path_id_new_onein_final_candidate4.csv')
df_tropical_v2_eval = pd.read_csv('evaluation_results_tropical_v2_shortest_path_id_new_onein_final_candidate4.csv')
df_transformer_eval = pd.read_csv('evaluation_results_transformer_shortest_path_id_new_onein_final_candidate4.csv')
df_edge_eval = pd.read_csv('evaluation_results_edge_transformer_shortest_path_id_new_onein_final_candidate4.csv')
df_gnn_eval = pd.read_csv('evaluation_results_gnn_shortest_path_id_new_onein_final_candidate4.csv')

# %%
df_tropical_eval = pd.read_csv('evaluation_results_tropical_shortest_path_ood_size_onein_final_candidate4.csv')
df_tropical_v2_eval = pd.read_csv('evaluation_results_tropical_v2_shortest_path_ood_size_onein_final_candidate4.csv')
df_transformer_eval = pd.read_csv('evaluation_results_transformer_shortest_path_ood_size_onein_final_candidate4.csv')
df_edge_eval = pd.read_csv('evaluation_results_edge_transformer_shortest_path_ood_size_onein_final_candidate4.csv')
df_gnn_eval = pd.read_csv('evaluation_results_gnn_shortest_path_ood_size_onein_final_candidate4.csv')

# %%
df_tropical_eval = pd.read_csv('evaluation_results_tropical_shortest_path_wood_onein_final_candidate4.csv')
df_tropical_v2_eval = pd.read_csv('evaluation_results_tropical_v2_shortest_path_wood_onein_final_candidate4.csv')
df_transformer_eval = pd.read_csv('evaluation_results_transformer_shortest_path_wood_onein_final_candidate4.csv')
df_edge_eval = pd.read_csv('evaluation_results_edge_transformer_shortest_path_wood_onein_final_candidate4.csv')
df_gnn_eval = pd.read_csv('evaluation_results_gnn_shortest_path_wood_onein_final_candidate4.csv')

# %%
df_tropical_eval["model_type"] = "tropical"
df_tropical_v2_eval["model_type"] = "tropical_v2"
df_transformer_eval["model_type"] = "transformer"
df_gnn_eval["model_type"] = "gnn"
df_edge_eval["model_type"] = "edge_transformer"


df_all_eval = pd.concat([df_gnn_eval, df_edge_eval, df_tropical_v2_eval],ignore_index=True)

df_all_eval.head()
# Out:
#   model_type   problem_type eval_mode  wood_problem  network_name  graph_seed  \
# 0        gnn  shortest_path  ood_size           NaN           NaN    10020005
# 1        gnn  shortest_path  ood_size           NaN           NaN    10020006
# 2        gnn  shortest_path  ood_size           NaN           NaN    10020007
# 3        gnn  shortest_path  ood_size           NaN           NaN    10020008
# 4        gnn  shortest_path  ood_size           NaN           NaN    10020009
#
#    n_nodes  n_edges  density  replication  source  sink  attack_limit  \
# 0      100      200      2.0            0       0    99             1
# 1      100      200      2.0            1       0    99             1
# 2      100      200      2.0            2       0    99             1
# 3      100      200      2.0            3       0    99             1
# 4      100      200      2.0            4       0    99             1
#
#    optimal_objective  predicted_objective  objective_gap  hamming_distance  \
# 0               57.0                   50       0.122807                 2
# 1               18.0                   14       0.222222                 2
# 2               35.0                   34       0.028571                 2
# 3               38.0                   29       0.236842                 2
# 4               28.0                   28       0.000000                 0
#
#    exact_match  num_correct_edges  num_predicted_attacks  num_optimal_attacks  \
# 0            0                  0                      1                    1
# 1            0                  0                      1                    1
# 2            0                  0                      1                    1
# 3            0                  0                      1                    1
# 4            1                  1                      1                    1
#
#    mip_solve_time  mip_total_time  inference_time  candidate_objective  \
# 0        0.173607        0.182503        0.166680                   53
# 1        0.042887        0.049982        0.001095                   18
# 2        0.047299        0.054273        0.000940                   35
# 3        0.042326        0.049928        0.000936                   36
# 4        0.043935        0.050819        0.000933                   28
#
#    candidate_objective_gap  candidate_pool_size  num_candidates  \
# 0                 0.070175                    5               5
# 1                 0.000000                    5               5
# 2                 0.000000                    5               5
# 3                 0.052632                    5               5
# 4                 0.000000                    5               5
#
#    candidate_search_time  hybrid_total_time  candidate_exact_match  \
# 0               0.013975           0.180656                      0
# 1               0.001861           0.002956                      1
# 2               0.002230           0.003171                      1
# 3               0.002040           0.002976                      0
# 4               0.001713           0.002646                      1
#
#    candidate_hamming_distance  candidate_correct_edges
# 0                           2                        0
# 1                           0                        1
# 2                           0                        1
# 3                           2                        0
# 4                           0                        1

# %%
summary = (
    df_all_eval.groupby(["model_type", "density"])
    .agg(
        count=("objective_gap", "count"),

        # Direct model prediction
        exact_match_avg=("exact_match", "mean"),
        exact_match_std=("exact_match", "std"),

        candidate_exact_match_avg=("candidate_exact_match", "mean"),
        candidate_exact_match_std=("candidate_exact_match", "std"),

        objective_gap_avg=("objective_gap", "mean"),
        objective_gap_median=("objective_gap", "median"),
        objective_gap_std=("objective_gap", "std"),

        candidate_objective_gap_avg=("candidate_objective_gap", "mean"),
        candidate_objective_gap_median=("candidate_objective_gap", "median"),
        candidate_objective_gap_std=("candidate_objective_gap", "std"),

        hamming_distance_avg=("hamming_distance", "mean"),
        hamming_distance_std=("hamming_distance", "std"),

        candidate_hamming_distance_avg=("candidate_hamming_distance", "mean"),
        candidate_hamming_distance_std=("candidate_hamming_distance", "std"),

        inference_time_avg=("inference_time", "mean"),
        inference_time_std=("inference_time", "std"),

        hybrid_total_time_avg=("hybrid_total_time", "mean"),
        hybrid_total_time_std=("hybrid_total_time", "std"),

        mip_solve_time_avg=("mip_solve_time", "mean"),
        mip_solve_time_std=("mip_solve_time", "std"),

        candidate_correct_edges_avg=("candidate_correct_edges", "mean"),
        candidate_correct_edges_std=("candidate_correct_edges", "std"),

        candidate_search_time_avg=("candidate_search_time", "mean"),
        candidate_search_time_std=("candidate_search_time", "std"),

        candidate_pool_size_avg=("candidate_pool_size", "mean"),
        num_candidates_avg=("num_candidates", "mean"),


    )
    .reset_index()
)

summary
# Out:
#           model_type  density  count  exact_match_avg  exact_match_std  \
# 0   edge_transformer      2.0    400           0.0625         0.242365
# 1   edge_transformer      2.5    400           0.0750         0.263721
# 2   edge_transformer      3.0    400           0.0700         0.255467
# 3   edge_transformer      4.0    400           0.0850         0.279231
# 4   edge_transformer      5.0    400           0.0775         0.267718
# 5   edge_transformer      6.0    400           0.1100         0.313282
# 6   edge_transformer      8.0    400           0.0850         0.279231
# 7                gnn      2.0    400           0.0725         0.259639
# 8                gnn      2.5    400           0.0750         0.263721
# 9                gnn      3.0    400           0.0750         0.263721
# 10               gnn      4.0    400           0.0725         0.259639
# 11               gnn      5.0    400           0.0850         0.279231
# 12               gnn      6.0    400           0.0875         0.282920
# 13               gnn      8.0    400           0.0900         0.286540
# 14       tropical_v2      2.0    400           0.0650         0.246835
# 15       tropical_v2      2.5    400           0.0800         0.271633
# 16       tropical_v2      3.0    400           0.0700         0.255467
# 17       tropical_v2      4.0    400           0.0850         0.279231
# 18       tropical_v2      5.0    400           0.1075         0.310136
# 19       tropical_v2      6.0    400           0.1100         0.313282
# 20       tropical_v2      8.0    400           0.0900         0.286540
#
#     candidate_exact_match_avg  candidate_exact_match_std  objective_gap_avg  \
# 0                      0.1150                   0.319421           0.150338
# 1                      0.1925                   0.394757           0.151349
# 2                      0.2100                   0.407818           0.154124
# 3                      0.2175                   0.413062           0.153344
# 4                      0.2650                   0.441886           0.138964
# 5                      0.2350                   0.424530           0.131967
# 6                      0.2800                   0.449561           0.141255
# 7                      0.1850                   0.388784           0.135483
# 8                      0.2375                   0.426084           0.146735
# 9                      0.2800                   0.449561           0.142637
# 10                     0.2250                   0.418105           0.152151
# 11                     0.2725                   0.445803           0.136618
# 12                     0.2275                   0.419743           0.135476
# 13                     0.2550                   0.436407           0.132950
# 14                     0.1875                   0.390801           0.135868
# 15                     0.2425                   0.429132           0.140205
# 16                     0.2825                   0.450779           0.143274
# 17                     0.2300                   0.421360           0.156511
# 18                     0.2725                   0.445803           0.131004
# 19                     0.2575                   0.437805           0.127453
# 20                     0.2475                   0.432100           0.148818
#
#     objective_gap_median  objective_gap_std  candidate_objective_gap_avg  \
# 0               0.142857           0.103322                     0.111302
# 1               0.141851           0.109916                     0.090265
# 2               0.140873           0.115035                     0.081839
# 3               0.140873           0.117289                     0.070926
# 4               0.111111           0.129572                     0.046845
# 5               0.117647           0.115828                     0.056709
# 6               0.125000           0.121895                     0.035929
# 7               0.122379           0.100875                     0.060106
# 8               0.140598           0.112870                     0.071126
# 9               0.129032           0.110914                     0.058315
# 10              0.137931           0.116463                     0.060735
# 11              0.117647           0.123753                     0.045478
# 12              0.125000           0.109926                     0.053619
# 13              0.113248           0.112749                     0.039705
# 14              0.126599           0.097287                     0.061871
# 15              0.131884           0.107516                     0.065516
# 16              0.131007           0.107789                     0.051450
# 17              0.142857           0.116844                     0.057716
# 18              0.109127           0.125589                     0.034234
# 19              0.115385           0.111998                     0.039862
# 20              0.133333           0.124276                     0.045253
#
#     candidate_objective_gap_median  candidate_objective_gap_std  \
# 0                     1.008475e-01                     0.097144
# 1                     6.936648e-02                     0.094379
# 2                     5.195682e-02                     0.093835
# 3                     3.333333e-02                     0.093314
# 4                     1.058464e-15                     0.080035
# 5                     6.562109e-15                     0.086172
# 6                     1.492737e-15                     0.068316
# 7                     4.800307e-02                     0.062565
# 8                     3.960784e-02                     0.085633
# 9                     2.107365e-02                     0.083148
# 10                    1.244723e-12                     0.084479
# 11                    7.177809e-16                     0.082767
# 12                    4.760172e-15                     0.083566
# 13                    2.203366e-15                     0.076959
# 14                    4.347826e-02                     0.066472
# 15                    2.740240e-02                     0.085013
# 16                    8.474110e-14                     0.074630
# 17                    5.622853e-14                     0.082012
# 18                    5.684342e-16                     0.064638
# 19                    2.215052e-15                     0.066936
# 20                    4.809828e-15                     0.070110
#
#     hamming_distance_avg  hamming_distance_std  \
# 0                 3.9125              2.206130
# 1                 3.5500              2.041548
# 2                 3.5475              2.050183
# 3                 3.5325              2.165796
# 4                 3.1225              1.800165
# 5                 3.2200              1.966282
# 6                 3.2825              1.931845
# 7                 3.6225              2.042161
# 8                 3.4350              1.992662
# 9                 3.3525              1.981934
# 10                3.6225              2.132219
# 11                3.2625              1.875470
# 12                3.3250              1.966989
# 13                3.3225              1.987049
# 14                3.6575              2.079906
# 15                3.4300              1.991234
# 16                3.3875              1.921347
# 17                3.5775              2.114277
# 18                3.1575              1.931845
# 19                3.2000              1.960768
# 20                3.2675              1.881434
#
#     candidate_hamming_distance_avg  candidate_hamming_distance_std  \
# 0                           3.5375                        2.280701
# 1                           3.0150                        2.207251
# 2                           2.8575                        2.138604
# 3                           2.8225                        2.221109
# 4                           2.4075                        1.961137
# 5                           2.6050                        1.997235
# 6                           2.3925                        2.089104
# 7                           2.8425                        2.074476
# 8                           2.6500                        2.058663
# 9                           2.3975                        2.007378
# 10                          2.7725                        2.140607
# 11                          2.4425                        2.075443
# 12                          2.6400                        2.053275
# 13                          2.4975                        2.076240
# 14                          2.8675                        2.107379
# 15                          2.6350                        2.051169
# 16                          2.3975                        2.042038
# 17                          2.7025                        2.148379
# 18                          2.2575                        1.885492
# 19                          2.4050                        1.941752
# 20                          2.5475                        2.016907
#
#     inference_time_avg  inference_time_std  hybrid_total_time_avg  \
# 0             0.002264            0.007809               0.064877
# 1             0.002072            0.000393               0.075343
# 2             0.002311            0.000687               0.091052
# 3             0.003042            0.001478               0.109346
# 4             0.004108            0.002728               0.128471
# 5             0.005305            0.003987               0.152951
# 6             0.008486            0.007002               0.198599
# 7             0.001497            0.008280               0.065282
# 8             0.001115            0.000085               0.077526
# 9             0.001134            0.000086               0.090995
# 10            0.001197            0.000153               0.110359
# 11            0.001311            0.000280               0.131085
# 12            0.001488            0.000480               0.153865
# 13            0.001974            0.001011               0.203058
# 14            0.007683            0.028324               0.066214
# 15            0.007242            0.002749               0.077062
# 16            0.008475            0.004529               0.093033
# 17            0.011214            0.006965               0.120681
# 18            0.015312            0.010861               0.144307
# 19            0.020655            0.016307               0.173218
# 20            0.033369            0.029213               0.224440
#
#     hybrid_total_time_std  mip_solve_time_avg  mip_solve_time_std  \
# 0                0.080293            0.256212            0.320461
# 1                0.091565            0.554963            0.939769
# 2                0.118291            0.866707            1.311248
# 3                0.134317            1.497537            1.952639
# 4                0.155451            2.013485            2.699456
# 5                0.184164            3.521100            4.422752
# 6                0.235386            5.477450            6.370992
# 7                0.079913            0.256905            0.325823
# 8                0.095605            0.553353            0.947546
# 9                0.119524            0.870285            1.316879
# 10               0.141325            1.500018            1.962111
# 11               0.161494            2.015985            2.718052
# 12               0.194107            3.533184            4.439264
# 13               0.252611            5.490238            6.388584
# 14               0.080958            0.257945            0.318293
# 15               0.091664            0.550868            0.936489
# 16               0.112020            0.863577            1.307939
# 17               0.139522            1.486311            1.957057
# 18               0.164986            2.005265            2.700317
# 19               0.196396            3.512833            4.423716
# 20               0.262526            5.475952            6.377251
#
#     candidate_correct_edges_avg  candidate_correct_edges_std  \
# 0                        1.1925                     0.843934
# 1                        1.4725                     1.023162
# 2                        1.5275                     1.035337
# 3                        1.5600                     1.133407
# 4                        1.7125                     1.143728
# 5                        1.6325                     1.177246
# 6                        1.7550                     1.288069
# 7                        1.5400                     1.017836
# 8                        1.6550                     1.074179
# 9                        1.7575                     1.188370
# 10                       1.5850                     1.160233
# 11                       1.6950                     1.172780
# 12                       1.6150                     1.193875
# 13                       1.7025                     1.254163
# 14                       1.5275                     0.975512
# 15                       1.6625                     1.098458
# 16                       1.7575                     1.164941
# 17                       1.6200                     1.170052
# 18                       1.7875                     1.189909
# 19                       1.7325                     1.250942
# 20                       1.6775                     1.306814
#
#     candidate_search_time_avg  candidate_search_time_std  \
# 0                    0.062613                   0.080107
# 1                    0.073271                   0.091410
# 2                    0.088741                   0.117984
# 3                    0.106304                   0.133637
# 4                    0.124363                   0.154201
# 5                    0.147646                   0.182235
# 6                    0.190113                   0.231830
# 7                    0.063785                   0.079708
# 8                    0.076411                   0.095563
# 9                    0.089861                   0.119483
# 10                   0.109161                   0.141263
# 11                   0.129774                   0.161364
# 12                   0.152377                   0.193893
# 13                   0.201084                   0.252074
# 14                   0.058532                   0.076148
# 15                   0.069819                   0.090620
# 16                   0.084558                   0.110432
# 17                   0.109466                   0.136082
# 18                   0.128995                   0.159494
# 19                   0.152563                   0.188354
# 20                   0.191071                   0.246677
#
#     candidate_pool_size_avg  num_candidates_avg
# 0                       7.0                50.2
# 1                       7.0                50.2
# 2                       7.0                50.2
# 3                       7.0                50.2
# 4                       7.0                50.2
# 5                       7.0                50.2
# 6                       7.0                50.2
# 7                       7.0                50.2
# 8                       7.0                50.2
# 9                       7.0                50.2
# 10                      7.0                50.2
# 11                      7.0                50.2
# 12                      7.0                50.2
# 13                      7.0                50.2
# 14                      7.0                50.2
# 15                      7.0                50.2
# 16                      7.0                50.2
# 17                      7.0                50.2
# 18                      7.0                50.2
# 19                      7.0                50.2
# 20                      7.0                50.2

# %%
def add_confidence_intervals(summary, metrics, confidence_multiplier=1.96):

    for metric in metrics:
        mean_col = f"{metric}_avg"
        std_col = f"{metric}_std"

        summary[f"{metric}_se"] = (summary[std_col] / np.sqrt(summary["count"]))

        summary[f"{metric}_ci_lower"] = (summary[mean_col] - confidence_multiplier * summary[f"{metric}_se"])

        summary[f"{metric}_ci_upper"] = (summary[mean_col] + confidence_multiplier * summary[f"{metric}_se"])

    return summary

# %%
metrics_for_ci = [
    # Direct model prediction
    "exact_match",
    "objective_gap",
    "hamming_distance",
    "inference_time",

    # Candidate search / hybrid
    "candidate_exact_match",
    "candidate_objective_gap",
    "candidate_hamming_distance",
    "candidate_search_time",
    "hybrid_total_time",

    # MIP benchmark
    "mip_solve_time",
]

summary = add_confidence_intervals(summary, metrics_for_ci)

# %%
def plot_metric_with_ci(summary, metric, xlabel="Arc-to-Node Ratio (m/n)", ylabel=None, title=None):
    
    plt.figure(figsize=(9, 6))

    for model, group in summary.groupby("model_type"):
        group = group.sort_values("density")

        line, = plt.plot(
            group["density"],
            group[f"{metric}_avg"],
            marker="o",
            label=model)

        plt.plot(
            group["density"],
            group[f"{metric}_ci_lower"],
            linestyle="--",
            color=line.get_color(),
            alpha=0.6)

        plt.plot(
            group["density"],
            group[f"{metric}_ci_upper"],
            linestyle="--",
            color=line.get_color(),
            alpha=0.6)

    plt.xlabel(xlabel)
    plt.ylabel(ylabel if ylabel else metric)
    plt.title(title if title else f"{metric} by Network Density")
    plt.legend(title="Model")
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
plot_metric_with_ci(
    summary,
    metric="objective_gap",
    ylabel="Average Objective Gap",
    title="Average Objective Gap by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="exact_match",
    ylabel="Average Exact Match",
    title="Average Exact Match by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="hamming_distance",
    ylabel="Average Hamming Distance",
    title="Average Hamming Distance by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="inference_time",
    ylabel="Average Model Inference Time",
    title="Average Model Inference Time by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_exact_match",
    ylabel="Average Candidate Exact Match",
    title="Average Candidate Exact Match by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_objective_gap",
    ylabel="Average Candidate Objective Gap",
    title="Average Candidate Objective Gap by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_hamming_distance",
    ylabel="Average Candidate Hamming Distance",
    title="Average Candidate Hamming Distance by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_search_time",
    ylabel="Average Candidate Search Time",
    title="Average Candidate Search Time by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="hybrid_total_time",
    ylabel="Average Candidate Search + Model Inference Time",
    title="Average Candidate Search + Model Inference Time by Network Density"
)
