# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_trop = pd.read_csv('training_log_tropical_v2_shortest_path_retrain_v2.csv')
df_trop.head()
# Out:
#     model_type  epoch  train_loss  val_loss  accuracy  precision    recall  \
# 0  tropical_v2      1    0.863709  0.596549  0.984700   0.435821  0.438438
# 1  tropical_v2      2    0.585021  0.535518  0.985134   0.451741  0.454454
# 2  tropical_v2      3    0.559504  0.526788  0.985134   0.451741  0.454454
# 3  tropical_v2      4    0.557652  0.523533  0.985053   0.448756  0.451451
# 4  tropical_v2      5    0.550201  0.512767  0.985432   0.462687  0.465465
#
#          f1   hamming  exact_match  average_gradient_norm  \
# 0  0.437126  3.367164     0.092537               3.252959
# 1  0.453094  3.271642     0.110448               4.685279
# 2  0.453094  3.271642     0.095522               5.616635
# 3  0.450100  3.289552     0.107463               6.232858
# 4  0.464072  3.205970     0.119403               5.847328
#
#    maximum_gradient_norm  best_epoch_so_far  epoch_time_seconds
# 0              26.638224               True            6.993923
# 1              18.235764               True            6.530164
# 2              31.695583               True            6.556322
# 3              46.080948               True            6.525912
# 4              33.995609               True            6.544356

# %%
df_trans = pd.read_csv('training_log_edge_transformer_shortest_path_retrain_v2.csv')
df_trans.head()
# Out:
#          model_type  epoch  train_loss  val_loss  accuracy  precision  \
# 0  edge_transformer      1    0.843377  0.741877  0.984022   0.410945
# 1  edge_transformer      2    0.679634  0.716120  0.984157   0.415920
# 2  edge_transformer      3    0.663187  0.707044  0.984239   0.418905
# 3  edge_transformer      4    0.652597  0.705152  0.984456   0.426866
# 4  edge_transformer      5    0.645755  0.699520  0.984591   0.431841
#
#      recall        f1   hamming  exact_match  average_gradient_norm  \
# 0  0.413413  0.412176  3.516418     0.068657               1.793781
# 1  0.418418  0.417166  3.486567     0.080597               1.944836
# 2  0.421421  0.420160  3.468657     0.083582               2.064991
# 3  0.429429  0.428144  3.420896     0.089552               2.263696
# 4  0.434434  0.433134  3.391045     0.089552               2.225589
#
#    maximum_gradient_norm  best_epoch_so_far  epoch_time_seconds
# 0              10.082198               True            4.896028
# 1               8.240819               True            4.235590
# 2              12.237167               True            4.215823
# 3              11.569022               True            4.218909
# 4               7.948503               True            4.293789

# %%
df_gnn = pd.read_csv('training_log_gnn_shortest_path_retrain_v2.csv')
df_gnn.head()
# Out:
#   model_type  epoch  train_loss  val_loss  accuracy  precision    recall  \
# 0        gnn      1    0.921112  0.666848  0.984184   0.416915  0.419419
# 1        gnn      2    0.601931  0.621071  0.984293   0.420896  0.423423
# 2        gnn      3    0.589059  0.603977  0.984347   0.422886  0.425425
# 3        gnn      4    0.583556  0.602403  0.984619   0.432836  0.435435
# 4        gnn      5    0.578608  0.594124  0.984863   0.441791  0.444444
#
#          f1   hamming  exact_match  average_gradient_norm  \
# 0  0.418164  3.480597     0.089552               1.158504
# 1  0.422156  3.456716     0.089552               2.007610
# 2  0.424152  3.444776     0.077612               1.981723
# 3  0.434132  3.385075     0.089552               2.200786
# 4  0.443114  3.331343     0.089552               2.222835
#
#    maximum_gradient_norm  best_epoch_so_far  epoch_time_seconds
# 0               7.035658               True            2.954248
# 1               7.500617               True            2.575725
# 2              14.339534               True            2.592821
# 3              10.169017               True            2.603992
# 4              14.666319               True            2.574286
