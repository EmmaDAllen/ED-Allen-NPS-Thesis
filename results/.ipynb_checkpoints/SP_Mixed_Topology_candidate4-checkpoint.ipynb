# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df_trop = pd.read_csv('training_log_tropical_shortest_path_mixed_topology.csv')
df_trop_v2 = pd.read_csv('training_log_tropical_v2_shortest_path_mixed_topology.csv')
df_trans = pd.read_csv('training_log_transformer_shortest_path_mixed_topology.csv')
df_edge = pd.read_csv('training_log_edge_transformer_shortest_path_mixed_topology.csv')
df_gnn = pd.read_csv('training_log_gnn_shortest_path_mixed_topology.csv')

# %%
df_trop["model_type"] = "tropical"
df_trop_v2["model_type"] = "tropical_v2"
df_trans["model_type"] = "transformer"
df_edge["model_type"] = "edge_transformer"
df_gnn["model_type"] = "gnn"

df_all = pd.concat([df_trop, df_trop_v2, df_trans, df_edge, df_gnn], ignore_index=True)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

sns.lineplot(
    data=df_all,
    x="epoch",
    y="train_loss",
    hue="model_type",
    ax=axes[0]
)

axes[0].set_title("Training Loss by Epoch")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Training Loss")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="val_loss",
    hue="model_type",
    ax=axes[1]
)

axes[1].set_title("Validation Loss by Epoch")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Validation Loss")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharex=True)

sns.lineplot(
    data=df_all,
    x="epoch",
    y="exact_match",
    hue="model_type",
    ax=axes[0, 0]
)
axes[0, 0].set_title("Exact Match by Epoch")
axes[0, 0].set_xlabel("Epoch")
axes[0, 0].set_ylabel("Exact Match Rate")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="hamming",
    hue="model_type",
    ax=axes[0, 1]
)
axes[0, 1].set_title("Hamming Distance by Epoch")
axes[0, 1].set_xlabel("Epoch")
axes[0, 1].set_ylabel("Hamming Distance")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="f1",
    hue="model_type",
    ax=axes[1, 0]
)
axes[1, 0].set_title("F1 Score by Epoch")
axes[1, 0].set_xlabel("Epoch")
axes[1, 0].set_ylabel("F1 Score")

sns.lineplot(
    data=df_all,
    x="epoch",
    y="epoch_time_seconds",
    hue="model_type",
    ax=axes[1, 1]
)
axes[1, 1].set_title("Epoch Time by Epoch")
axes[1, 1].set_xlabel("Epoch")
axes[1, 1].set_ylabel("Time (seconds)")

plt.tight_layout()
plt.show()

# %%
df_tropical_eval = pd.read_csv('evaluation_results_tropical_shortest_path_id_new_mixed_topology_candidate4.csv')
df_tropical_v2_eval = pd.read_csv('evaluation_results_tropical_v2_shortest_path_id_new_mixed_topology_candidate4.csv')
df_transformer_eval = pd.read_csv('evaluation_results_transformer_shortest_path_id_new_mixed_topology_candidate4.csv')
df_edge_eval = pd.read_csv('evaluation_results_edge_transformer_shortest_path_id_new_mixed_topology_candidate4.csv')
df_gnn_eval = pd.read_csv('evaluation_results_gnn_shortest_path_id_new_mixed_topology_candidate4.csv')

# %%
df_tropical_eval = pd.read_csv('evaluation_results_tropical_shortest_path_ood_size_mixed_topology_candidate4.csv')
df_tropical_v2_eval = pd.read_csv('evaluation_results_tropical_v2_shortest_path_ood_size_mixed_topology_candidate4.csv')
df_transformer_eval = pd.read_csv('evaluation_results_transformer_shortest_path_ood_size_mixed_topology_candidate4.csv')
df_edge_eval = pd.read_csv('evaluation_results_edge_transformer_shortest_path_ood_size_mixed_topology_candidate4.csv')
df_gnn_eval = pd.read_csv('evaluation_results_gnn_shortest_path_ood_size_mixed_topology_candidate4.csv')

# %%
df_tropical_eval = pd.read_csv('evaluation_results_tropical_shortest_path_wood_mixed_topology_candidate4.csv')
df_tropical_v2_eval = pd.read_csv('evaluation_results_tropical_v2_shortest_path_wood_mixed_topology_candidate4.csv')
df_transformer_eval = pd.read_csv('evaluation_results_transformer_shortest_path_wood_mixed_topology_candidate4.csv')
df_edge_eval = pd.read_csv('evaluation_results_edge_transformer_shortest_path_wood_mixed_topology_candidate4.csv')
df_gnn_eval = pd.read_csv('evaluation_results_gnn_shortest_path_wood_mixed_topology_candidate4.csv')

# %%
df_tropical_eval["model_type"] = "tropical"
df_tropical_v2_eval["model_type"] = "tropical_v2"
df_transformer_eval["model_type"] = "transformer"
df_gnn_eval["model_type"] = "gnn"
df_edge_eval["model_type"] = "edge_transformer"


df_all_eval = pd.concat([df_gnn_eval, df_edge_eval, df_tropical_v2_eval],ignore_index=True)

df_all_eval.head()
# Out:
#   model_type   problem_type eval_mode  wood_problem  network_name  graph_seed  \
# 0        gnn  shortest_path      wood            13           NaN          18
# 1        gnn  shortest_path      wood            15           NaN          20
# 2        gnn  shortest_path      wood            17           NaN          22
# 3        gnn  shortest_path      wood            19           NaN          24
# 4        gnn  shortest_path      wood            14           NaN          19
#
#    n_nodes  n_edges   density  replication  ...  inference_time  \
# 0       51      188  3.686275          NaN  ...        0.168336
# 1       66      254  3.848485          NaN  ...        0.001187
# 2       83      330  3.975904          NaN  ...        0.001168
# 3      146      618  4.232877          NaN  ...        0.001690
# 4       51      188  3.686275          NaN  ...        0.001116
#
#    candidate_objective  candidate_objective_gap  candidate_pool_size  \
# 0                   22                 0.083333                    9
# 1                   19                 0.136364                    9
# 2                   17                 0.055556                    9
# 3                   25                 0.107143                    9
# 4                   13                 0.315789                   14
#
#    num_candidates  candidate_search_time  hybrid_total_time  \
# 0             126               0.034973           0.203309
# 1             126               0.044786           0.045973
# 2             126               0.058236           0.059404
# 3             126               0.109628           0.111318
# 4            1001               0.264153           0.265269
#
#    candidate_exact_match  candidate_hamming_distance  candidate_correct_edges
# 0                      0                           6                        2
# 1                      0                           6                        2
# 2                      0                           6                        2
# 3                      0                           8                        1
# 4                      0                          12                        4
#
# [5 rows x 33 columns]

# %%
summary = (
    df_all_eval.groupby(["model_type", "density"])
    .agg(
        count=("objective_gap", "count"),

        # Direct model prediction
        objective_gap_avg=("objective_gap", "mean"),
        objective_gap_median=("objective_gap", "median"),
        objective_gap_std=("objective_gap", "std"),

        candidate_objective_gap_avg=("candidate_objective_gap", "mean"),
        candidate_objective_gap_median=("candidate_objective_gap", "median"),
        candidate_objective_gap_std=("candidate_objective_gap", "std"),
        exact_match_avg=("exact_match", "mean"),
        exact_match_std=("exact_match", "std"),

        candidate_exact_match_avg=("candidate_exact_match", "mean"),
        candidate_exact_match_std=("candidate_exact_match", "std"),

        hamming_distance_avg=("hamming_distance", "mean"),
        hamming_distance_std=("hamming_distance", "std"),

        candidate_hamming_distance_avg=("candidate_hamming_distance", "mean"),
        candidate_hamming_distance_std=("candidate_hamming_distance", "std"),

        inference_time_avg=("inference_time", "mean"),
        inference_time_std=("inference_time", "std"),

        hybrid_total_time_avg=("hybrid_total_time", "mean"),
        hybrid_total_time_std=("hybrid_total_time", "std"),

        mip_solve_time_avg=("mip_solve_time", "mean"),
        mip_solve_time_std=("mip_solve_time", "std"),

        candidate_correct_edges_avg=("candidate_correct_edges", "mean"),
        candidate_correct_edges_std=("candidate_correct_edges", "std"),

        candidate_search_time_avg=("candidate_search_time", "mean"),
        candidate_search_time_std=("candidate_search_time", "std"),

        candidate_pool_size_avg=("candidate_pool_size", "mean"),
        num_candidates_avg=("num_candidates", "mean"),


    )
    .reset_index()
)

summary
# Out:
#           model_type   density  count  objective_gap_avg  \
# 0   edge_transformer  3.686275      2           0.320175
# 1   edge_transformer  3.848485      2           0.181818
# 2   edge_transformer  3.975904      2           0.229167
# 3   edge_transformer  4.232877      2           0.183036
# 4                gnn  3.686275      2           0.273026
# 5                gnn  3.848485      2           0.204545
# 6                gnn  3.975904      2           0.229167
# 7                gnn  4.232877      2           0.147321
# 8        tropical_v2  3.686275      2           0.199561
# 9        tropical_v2  3.848485      2           0.181818
# 10       tropical_v2  3.975904      2           0.229167
# 11       tropical_v2  4.232877      2           0.183036
#
#     objective_gap_median  objective_gap_std  candidate_objective_gap_avg  \
# 0               0.320175       2.170942e-01                     0.278509
# 1               0.181818       5.748570e-12                     0.181818
# 2               0.229167       8.838835e-02                     0.229167
# 3               0.183036       6.313453e-03                     0.183036
# 4               0.273026       2.093408e-01                     0.199561
# 5               0.204545       9.642365e-02                     0.204545
# 6               0.229167       8.838835e-02                     0.173611
# 7               0.147321       5.682108e-02                     0.147321
# 8               0.199561       1.643713e-01                     0.173246
# 9               0.181818       5.748570e-12                     0.159091
# 10              0.229167       8.838835e-02                     0.173611
# 11              0.183036       6.313453e-03                     0.147321
#
#     candidate_objective_gap_median  candidate_objective_gap_std  \
# 0                         0.278509                 2.760198e-01
# 1                         0.181818                 5.748570e-12
# 2                         0.229167                 8.838835e-02
# 3                         0.183036                 6.313453e-03
# 4                         0.199561                 1.643713e-01
# 5                         0.204545                 9.642365e-02
# 6                         0.173611                 1.669558e-01
# 7                         0.147321                 5.682108e-02
# 8                         0.173246                 1.271552e-01
# 9                         0.159091                 3.214122e-02
# 10                        0.173611                 1.669558e-01
# 11                        0.147321                 5.682108e-02
#
#     exact_match_avg  ...  hybrid_total_time_avg  hybrid_total_time_std  \
# 0               0.0  ...               0.227685               0.042619
# 1               0.0  ...               0.207273               0.225562
# 2               0.0  ...               0.260506               0.283373
# 3               0.0  ...               0.489065               0.533027
# 4               0.0  ...               0.234289               0.043812
# 5               0.0  ...               0.202745               0.221709
# 6               0.0  ...               0.257806               0.280582
# 7               0.0  ...               0.496521               0.544760
# 8               0.0  ...               0.505343               0.336142
# 9               0.0  ...               0.208206               0.222780
# 10              0.0  ...               0.261348               0.279517
# 11              0.0  ...               0.500795               0.541762
#
#     mip_solve_time_avg  mip_solve_time_std  candidate_correct_edges_avg  \
# 0             0.456882            0.083465                          2.0
# 1             1.198751            1.337601                          3.0
# 2             2.371894            1.540227                          1.0
# 3             6.427580            3.153314                          1.0
# 4             0.465480            0.094936                          3.0
# 5             1.201463            1.341002                          2.5
# 6             2.375114            1.544709                          2.0
# 7             6.434696            3.150940                          0.5
# 8             0.472000            0.100690                          2.5
# 9             1.201385            1.338632                          2.5
# 10            2.430661            1.606792                          2.0
# 11            6.397516            3.197750                          0.5
#
#     candidate_correct_edges_std  candidate_search_time_avg  \
# 0                      0.000000                   0.145175
# 1                      1.414214                   0.205081
# 2                      0.000000                   0.258297
# 3                      1.414214                   0.486095
# 4                      1.414214                   0.149563
# 5                      0.707107                   0.201590
# 6                      0.000000                   0.256394
# 7                      0.707107                   0.494839
# 8                      0.707107                   0.148320
# 9                      0.707107                   0.202231
# 10                     0.000000                   0.254925
# 11                     0.707107                   0.493889
#
#     candidate_search_time_std  candidate_pool_size_avg  num_candidates_avg
# 0                    0.156617                     11.5               563.5
# 1                    0.225953                     11.5               563.5
# 2                    0.283176                     11.5               563.5
# 3                    0.533418                     11.5               563.5
# 4                    0.162054                     11.5               563.5
# 5                    0.221755                     11.5               563.5
# 6                    0.280238                     11.5               563.5
# 7                    0.544771                     11.5               563.5
# 8                    0.160479                     11.5               563.5
# 9                    0.222961                     11.5               563.5
# 10                   0.278745                     11.5               563.5
# 11                   0.541719                     11.5               563.5
#
# [12 rows x 29 columns]

# %%
def add_confidence_intervals(summary, metrics, confidence_multiplier=1.96):

    for metric in metrics:
        mean_col = f"{metric}_avg"
        std_col = f"{metric}_std"

        summary[f"{metric}_se"] = (summary[std_col] / np.sqrt(summary["count"]))

        summary[f"{metric}_ci_lower"] = (summary[mean_col] - confidence_multiplier * summary[f"{metric}_se"])

        summary[f"{metric}_ci_upper"] = (summary[mean_col] + confidence_multiplier * summary[f"{metric}_se"])

    return summary

# %%
metrics_for_ci = [
    # Direct model prediction
    "exact_match",
    "objective_gap",
    "hamming_distance",
    "inference_time",

    # Candidate search / hybrid
    "candidate_exact_match",
    "candidate_objective_gap",
    "candidate_hamming_distance",
    "candidate_search_time",
    "hybrid_total_time",

    # MIP benchmark
    "mip_solve_time",
]

summary = add_confidence_intervals(summary, metrics_for_ci)

# %%
def plot_metric_with_ci(summary, metric, xlabel="Arc-to-Node Ratio (m/n)", ylabel=None, title=None):
    
    plt.figure(figsize=(9, 6))

    for model, group in summary.groupby("model_type"):
        group = group.sort_values("density")

        line, = plt.plot(
            group["density"],
            group[f"{metric}_avg"],
            marker="o",
            label=model)

        plt.plot(
            group["density"],
            group[f"{metric}_ci_lower"],
            linestyle="--",
            color=line.get_color(),
            alpha=0.6)

        plt.plot(
            group["density"],
            group[f"{metric}_ci_upper"],
            linestyle="--",
            color=line.get_color(),
            alpha=0.6)

    plt.xlabel(xlabel)
    plt.ylabel(ylabel if ylabel else metric)
    plt.title(title if title else f"{metric} by Network Density")
    plt.legend(title="Model")
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
plot_metric_with_ci(
    summary,
    metric="objective_gap",
    ylabel="Average Objective Gap",
    title="Average Objective Gap by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="exact_match",
    ylabel="Average Exact Match",
    title="Average Exact Match by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="hamming_distance",
    ylabel="Average Hamming Distance",
    title="Average Hamming Distance by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="inference_time",
    ylabel="Average Model Inference Time",
    title="Average Model Inference Time by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_objective_gap",
    ylabel="Average Candidate Objective Gap",
    title="Average Candidate Objective Gap by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_exact_match",
    ylabel="Average Candidate Exact Match",
    title="Average Candidate Exact Match by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_hamming_distance",
    ylabel="Average Candidate Hamming Distance",
    title="Average Candidate Hamming Distance by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="candidate_search_time",
    ylabel="Average Candidate Search Time",
    title="Average Candidate Search Time by Network Density"
)

# %%
plot_metric_with_ci(
    summary,
    metric="hybrid_total_time",
    ylabel="Average Candidate Search + Model Inference Time",
    title="Average Candidate Search + Model Inference Time by Network Density"
)
